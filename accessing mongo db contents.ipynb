# %%
import pymongo
import pandas as pd

# %%
client=pymongo.MongoClient('mongodb://127.0.0.1:27017')

# %%
db = client["Employee"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'Employee')

# %%
mycoll=db["Education US"]

# %%
print(mycoll)
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'Employee'), 'Education US')

# %%
one_rec=mycoll.find_one()

# %%
print(one_rec)
# Out:
# {'_id': ObjectId('61ba6dcb4ed3d5548afae8f5'), 'State': 'US', 'Area name': 'United States', 'Percent of adults with less than a high school diploma, 1970': 47.7, 'Percent of adults with a high school diploma only, 1970': 31.1, 'Percent of adults completing some college (1-3 years), 1970': 10.6, 'Percent of adults completing four years of college or higher, 1970': 10.7, 'Percent of adults with less than a high school diploma, 1980': 33.5, 'Percent of adults with a high school diploma only, 1980': 34.6, 'Percent of adults completing some college (1-3 years), 1980': 15.7, 'Percent of adults completing four years of college or higher, 1980': 16.2, 'Percent of adults with less than a high school diploma, 1990': 24.8, 'Percent of adults with a high school diploma only, 1990': 30, "Percent of adults completing some college or associate's degree, 1990": 24.9, "Percent of adults with a bachelor's degree or higher, 1990": 20.3, 'Percent of adults with less than a high school diploma, 2000': 19.
# ...

# %%
all_rec=mycoll.find()

# %%
for records in mycoll.find():
    print(records)
# Out:
# {'_id': ObjectId('61ba6dcb4ed3d5548afae8f5'), 'State': 'US', 'Area name': 'United States', 'Percent of adults with less than a high school diploma, 1970': 47.7, 'Percent of adults with a high school diploma only, 1970': 31.1, 'Percent of adults completing some college (1-3 years), 1970': 10.6, 'Percent of adults completing four years of college or higher, 1970': 10.7, 'Percent of adults with less than a high school diploma, 1980': 33.5, 'Percent of adults with a high school diploma only, 1980': 34.6, 'Percent of adults completing some college (1-3 years), 1980': 15.7, 'Percent of adults completing four years of college or higher, 1980': 16.2, 'Percent of adults with less than a high school diploma, 1990': 24.8, 'Percent of adults with a high school diploma only, 1990': 30, "Percent of adults completing some college or associate's degree, 1990": 24.9, "Percent of adults with a bachelor's degree or higher, 1990": 20.3, 'Percent of adults with less than a high school diploma, 2000': 19.
# ...

# %%
all_rec=mycoll.find()

# %%
print(all_rec)

# %%
list_1=list(all_rec)

# %%
print(list_1)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
def Convert(a):
    it = iter(a)
    res_dct = dict(zip(it, it))
    return res_dct

# %%
print(Convert(list_1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-370-8d7d5d458fe7> in <module>
# ----> 1 print(Convert(list_1))
#
# <ipython-input-369-c27e1d596b17> in Convert(a)
#       1 def Convert(a):
#       2     it = iter(a)
# ----> 3     res_dct = dict(zip(it, it))
#       4     return res_dct
#
# TypeError: unhashable type: 'dict'

# %%
df =pd.DataFrame(list_1)

# %%
df
# Out:
#                            _id State          Area name  \
# 0     61ba6dcb4ed3d5548afae8f5    US      United States
# 1     61ba6dcb4ed3d5548afae8f6    AL            Alabama
# 2     61ba6dcb4ed3d5548afae8f7    AL     Autauga County
# 3     61ba6dcb4ed3d5548afae8f8    AL     Baldwin County
# 4     61ba6dcb4ed3d5548afae8f9    AL     Barbour County
# ...                        ...   ...                ...
# 3172  61ba6dcb4ed3d5548afaf559    WY  Sweetwater County
# 3173  61ba6dcb4ed3d5548afaf55a    WY       Teton County
# 3174  61ba6dcb4ed3d5548afaf55b    WY       Uinta County
# 3175  61ba6dcb4ed3d5548afaf55c    WY    Washakie County
# 3176  61ba6dcb4ed3d5548afaf55d    WY      Weston County
#
#       Percent of adults with less than a high school diploma, 1970  \
# 0                                                  47.7
# 1                                                  58.7
# 2                                                  54.8
# ...

# %%
import pandas as pd
import mysql.connector
from mysql.connector import Error

# %%
print(df)
# Out:
#                            _id State          Area name  \
# 0     61ba6dcb4ed3d5548afae8f5    US      United States
# 1     61ba6dcb4ed3d5548afae8f6    AL            Alabama
# 2     61ba6dcb4ed3d5548afae8f7    AL     Autauga County
# 3     61ba6dcb4ed3d5548afae8f8    AL     Baldwin County
# 4     61ba6dcb4ed3d5548afae8f9    AL     Barbour County
# ...                        ...   ...                ...
# 3172  61ba6dcb4ed3d5548afaf559    WY  Sweetwater County
# 3173  61ba6dcb4ed3d5548afaf55a    WY       Teton County
# 3174  61ba6dcb4ed3d5548afaf55b    WY       Uinta County
# 3175  61ba6dcb4ed3d5548afaf55c    WY    Washakie County
# 3176  61ba6dcb4ed3d5548afaf55d    WY      Weston County
#
#       Percent of adults with less than a high school diploma, 1970  \
# 0                                                  47.7
# 1                                                  58.7
# 2                                                  54.8
# ...

# %%
pip install mysqlclient
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas.io import sql
import MySQLdb

# %%
from sqlalchemy import create_engine
my_conn=create_engine("mysql+mysqldb://root:root@localhost/employee1")

# %%
df.to_sql(con=my_conn,name='fs1', index=False,if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# ...

# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2

# %%
DB_Host="ec2-44-199-83-229.compute-1.amazonaws.com"
DB_Name="d9av68tk7g7fl8"
DB_User="eafdrsqmhulftf"
DB_Pass="3358e6e49c69151da31ee9130f1bdfd6c330782decd405a31a06702b8231966c"

# %%
conn=psycopg2.connect(dbname=DB_Name,user=DB_User,password=DB_Pass,host=DB_Host)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://eafdrsqmhulftf:3358e6e49c69151da31ee9130f1bdfd6c330782decd405a31a06702b8231966c@ec2-44-199-83-229.compute-1.amazonaws.com:5432/d9av68tk7g7fl8')
